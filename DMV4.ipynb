# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('RealEstate_Prices.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1003  1004          90       RL          NaN    11500   Pave   NaN      IR1
# 1158  1159          20       RL         92.0    11932   Pave   NaN      Reg
# 1325  1326          30       RM         40.0     3636   Pave   NaN      Reg
# 707    708         120       RL         48.0     6240   Pave   NaN      Reg
# 763    764          60       RL         82.0     9430   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1003         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1158         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1325         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 707          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 763          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('[^\w\s]', '')
df.columns = df.columns.str.lower()
# Out:
# <ipython-input-13-b47332da7808>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('[^\w\s]', '')

# %%
df.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   landcontour utilities  ... poolarea poolqc fence miscfeature miscval mosold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   yrsold  saletype  salecondition  saleprice
# ...

# %% [markdown]
# ## **Handle missing values in the dataset, deciding on an appropriate strategy (e.g.,imputation or removal)**

# %%
missing_values = df.isnull().sum()
df.fillna(df.mean(), inplace=True)
df.fillna(df.mode().iloc[0], inplace=True)
# Out:
# <ipython-input-15-ba093b20a012>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
neighborhood_demographics = pd.read_csv("/content/drive/MyDrive/DMV Datasets/RealEstate_Prices_test.csv")

neighborhood_demographics.columns = neighborhood_demographics.columns.str.replace(' ', '_')
neighborhood_demographics.columns = neighborhood_demographics.columns.str.replace('[^\w\s]', '')
neighborhood_demographics.columns = neighborhood_demographics.columns.str.lower()

print("Main Dataset Columns:")
print(df.columns)
print("\nAdditional Dataset Columns:")
print(neighborhood_demographics.columns)

merged_df = pd.concat([df, neighborhood_demographics], ignore_index=True)
# Out:
# Main Dataset Columns:
# Index(['id', 'mssubclass', 'mszoning', 'lotfrontage', 'lotarea', 'street',
#        'alley', 'lotshape', 'landcontour', 'utilities', 'lotconfig',
#        'landslope', 'neighborhood', 'condition1', 'condition2', 'bldgtype',
#        'housestyle', 'overallqual', 'overallcond', 'yearbuilt', 'yearremodadd',
#        'roofstyle', 'roofmatl', 'exterior1st', 'exterior2nd', 'masvnrtype',
#        'masvnrarea', 'exterqual', 'extercond', 'foundation', 'bsmtqual',
#        'bsmtcond', 'bsmtexposure', 'bsmtfintype1', 'bsmtfinsf1',
#        'bsmtfintype2', 'bsmtfinsf2', 'bsmtunfsf', 'totalbsmtsf', 'heating',
#        'heatingqc', 'centralair', 'electrical', '1stflrsf', '2ndflrsf',
#        'lowqualfinsf', 'grlivarea', 'bsmtfullbath', 'bsmthalfbath', 'fullbath',
#        'halfbath', 'bedroomabvgr', 'kitchenabvgr', 'kitchenqual',
#        'totrmsabvgrd', 'functional', 'fireplaces', 'fireplacequ', 'garagetype',
# ...

# %%
merged_df.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1   2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2   3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3   4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4   5          60       RL         84.0    14260   Pave  Grvl      IR1
#
#   landcontour utilities  ... poolarea poolqc  fence miscfeature miscval  \
# 0         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 1         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 2         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 3         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 4         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
#
#   mosold yrsold  saletype  salecondition  saleprice
# 0      2   2008        WD         Normal   208500.0
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
merged_df.shape
# Out:
# (2919, 81)

# %%
missing_values = df.isnull().sum()
print(missing_values)
df.fillna(df.mean(), inplace=True)
df.fillna(df.mode().iloc[0], inplace=True)
# Out:
# id               0
# mssubclass       0
# mszoning         0
# lotfrontage      0
# lotarea          0
#                 ..
# mosold           0
# yrsold           0
# saletype         0
# salecondition    0
# saleprice        0
# Length: 81, dtype: int64
# <ipython-input-33-3b44639e7a6e>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %% [markdown]
# ## **Filter and subset the data based on specific criteria**

# %% [markdown]
# #### **1. Filtering by Time Period**

# %%
year_to_filter = 2007
filtered_by_year = merged_df[merged_df['yrsold'] == year_to_filter]
filtered_by_year.sample(5)
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 2310  2311         120       RL         48.0     3242   Pave   NaN      Reg
# 2501  2502          50       RL         60.0    11100   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave  Grvl      Reg
# 2333  2334          60       RL         83.0    10790   Pave   NaN      Reg
# 2316  2317          20       RL         88.0    12216   Pave   NaN      IR1
#
#      landcontour utilities  ... poolarea poolqc  fence miscfeature miscval  \
# 2310         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2501         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1447         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 2333         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2316         Lvl    AllPub  ...        0    NaN    NaN        Shed    2000
#
#      mosold yrsold  saletype  salecondition  saleprice
# ...

# %% [markdown]
# #### **Filtering by Property Type**

# %%
property_type_to_filter = 'Duplex'
filtered_by_property_type = merged_df[merged_df['bldgtype'] == property_type_to_filter]
filtered_by_property_type.sample(5)
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 1840  1841          90       RL          NaN    10547   Pave   NaN      IR1
# 1861  1862          90       RL          NaN    11855   Pave   NaN      Reg
# 1863  1864          90       RL          NaN     7976   Pave   NaN      Reg
# 2766  2767          90       RL         60.0     8544   Pave   NaN      Reg
# 454    455          90       RL         63.0     9297   Pave  Grvl      Reg
#
#      landcontour utilities  ... poolarea poolqc  fence miscfeature miscval  \
# 1840         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1861         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1863         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2766         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 454          Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
#
#      mosold yrsold  saletype  salecondition  saleprice
# ...

# %% [markdown]
# #### **Filtering by Location**

# %%
neighborhood_to_filter = 'CollgCr'
filtered_by_neighborhood = merged_df[merged_df['neighborhood'] == neighborhood_to_filter]
filtered_by_neighborhood.sample(5)
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 2853  2854         120       RM         37.0     4435   Pave   NaN      Reg
# 36      37          20       RL        112.0    10859   Pave  Grvl      Reg
# 1582  1583          20       RL         80.0    10389   Pave   NaN      Reg
# 1237  1238          60       RL         41.0    12393   Pave  Grvl      IR2
# 2835  2836          60       RL         78.0     9316   Pave   NaN      IR1
#
#      landcontour utilities  ... poolarea poolqc  fence miscfeature miscval  \
# 2853         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 36           Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 1582         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1237         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 2835         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      mosold yrsold  saletype  salecondition  saleprice
# ...

# %% [markdown]
# ## **Handle categorical variables by encoding them appropriately**

# %%
categorical_cols = ['mszoning', 'street', 'alley', 'lotshape', 'landcontour', 'lotconfig', 'neighborhood', 'condition1', 'condition2', 'bldgtype', 'housestyle', 'roofstyle', 'roofmatl', 'exterqual', 'extercond', 'foundation', 'bsmtqual', 'bsmtcond', 'bsmtexposure', 'bsmtfintype1', 'bsmtfintype2', 'heating', 'heatingqc', 'centralair', 'electrical', 'kitchenqual', 'functional', 'fireplacequ', 'garagetype', 'garagefinish', 'garagequal', 'garagecond', 'paveddrive', 'poolqc', 'fence', 'miscfeature', 'saletype', 'salecondition']

merged_df_encoded = pd.get_dummies(merged_df, columns=categorical_cols)
merged_df_encoded.sample(5)
# Out:
#         id  mssubclass  lotfrontage  lotarea utilities landslope  overallqual  \
# 520    521         190         60.0    10800    AllPub       Gtl            4
# 20      21          60        101.0    14215    AllPub       Gtl            8
# 2447  2448          70         53.0     9863    AllPub       Gtl            6
# 2849  2850          60         67.0    10566    AllPub       Gtl            8
# 2512  2513          60          NaN     8883    AllPub       Gtl            7
#
#       overallcond  yearbuilt  yearremodadd  ... saletype_ConLw saletype_New  \
# 520             7       1900          2000  ...              0            0
# 20              5       2005          2006  ...              0            1
# 2447            6       1927          1950  ...              0            0
# 2849            5       1999          1999  ...              0            0
# 2512            5       1988          1988  ...              0            0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

column_to_encode = 'exterqual'

label_encoder = LabelEncoder()
merged_df[column_to_encode + '_encoded'] = label_encoder.fit_transform(merged_df[column_to_encode])

# %%
merged_df[column_to_encode + '_encoded']
# Out:
# 0       2
# 1       3
# 2       2
# 3       3
# 4       2
#        ..
# 2914    3
# 2915    3
# 2916    3
# 2917    3
# 2918    3
# Name: exterqual_encoded, Length: 2919, dtype: int64

# %% [markdown]
# ### **Average Sale Prices by Neighborhood**

# %%
average_sale_prices_neighborhood = merged_df.groupby('neighborhood')['saleprice'].mean()

print("Average Sale Prices by Neighborhood:")
print(average_sale_prices_neighborhood)
# Out:
# Average Sale Prices by Neighborhood:
# neighborhood
# Blmngtn    194870.882353
# Blueste    137500.000000
# BrDale     104493.750000
# BrkSide    124834.051724
# ClearCr    212565.428571
# CollgCr    197965.773333
# Crawfor    210624.725490
# Edwards    128219.700000
# Gilbert    192854.506329
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# NWAmes     189050.068493
# NoRidge    335295.317073
# NridgHt    316270.623377
# OldTown    128225.300885
# SWISU      142591.360000
# Sawyer     136793.135135
# SawyerW    186555.796610
# Somerst    225379.837209
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Name: saleprice, dtype: float64

# %% [markdown]
# ### **Average Sale Prices by Property Type:**

# %%
average_sale_prices_property_type = merged_df.groupby('bldgtype')['saleprice'].mean()
print("\nAverage Sale Prices by Property Type:")
average_sale_prices_property_type
# Out:
# Average Sale Prices by Property Type:
# bldgtype
# 1Fam      185763.807377
# 2fmCon    128432.258065
# Duplex    133541.076923
# Twnhs     135911.627907
# TwnhsE    181959.342105
# Name: saleprice, dtype: float64

# %% [markdown]
# ## **Identify and handle outliers or extreme values**

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['saleprice'])
plt.title('Box Plot of Sale Price')
plt.ylabel('Sale Price')
# Out:
# Text(0, 0.5, 'Sale Price')

# %%
from scipy.stats import zscore
z_scores = zscore(df['saleprice'])
outliers = (z_scores > 3) | (z_scores < -3)
merged_df_no_outliers = df[~outliers]

# %%
outliers.sum()
# Out:
# 22

# %%
merged_df_no_outliers.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1   2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2   3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3   4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4   5          60       RL         84.0    14260   Pave  Grvl      IR1
#
#   landcontour utilities  ... poolarea poolqc  fence miscfeature miscval  \
# 0         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 1         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 2         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 3         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 4         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
#
#   mosold yrsold  saletype  salecondition  saleprice
# 0      2   2008        WD         Normal     208500
# ...
